# %%
# código para criar gráfico 2D força elastica em função do número de elasticos

import numpy as np  
import matplotlib.pyplot as plt 
x= 919
y= 98.11

def P(n): return n*0.10676

n = np.linspace(0,1000)  
plt.title('Força Elastica em função de número de elasticos')

plt.plot(n, P(n))
plt.plot(x,y,marker="o")
plt.xlabel('Número de elasticos')
plt.ylabel('Força(N)')


plt.draw()
plt.savefig('forca elastica.png',dpi=100)
plt.show()

# %%
# Grafico 2D pressao melancia com o crescimento no número de elasticos

import numpy as np  
import matplotlib.pyplot as plt 

def P(n): return n*42.5
n = np.linspace(0,710)  
plt.plot(n,P(n))

plt.title('Pressão em função do número de elasticos')
plt.xlabel('Número de elasticos')
plt.ylabel('Pressão em Pascal(Pa)')

plt.grid()  
plt.savefig('pressao-grafico.png')
plt.show()

# %%
import numpy as np  
import matplotlib.pyplot as plt

area=0.002512

for n in range(1,910):
    area=area*1.001
    def y(area): return n*(0.10676/area)
    
plt.title('Pressão em função do crescimento da área')
plt.xlabel('Aumento da área conforme deformação dos elasticos')
plt.ylabel('Pressão em Pascal(Pa)')
    
area = np.linspace(0,40)  
plt.xlim((0.025,30))
plt.ylim((0,100))
plt.plot(area,y(area))
plt.savefig('diminuicao-da-pressao-em-funcao-da-area')
plt.show()
# Out:
# <ipython-input-105-14f895072431>:8: RuntimeWarning: divide by zero encountered in true_divide
#   def y(area): return n*(0.10676/area)
