# %%
# código para criar gráfico 2D energia potencial


import numpy as np  
import matplotlib.pyplot as plt 

def P(n): return n*0.006704528
n = np.linspace(0,710)  
plt.plot(n, P(n) )
  
plt.grid()  
plt.show()

# %%
# Grafico 2D pressao melancia com o crescimento no número de elasticos

import numpy as np  
import matplotlib.pyplot as plt 

def P(n): return n*42.5
x = np.linspace(0,710)  
plt.plot(n,P(n))
  
plt.grid()  
plt.show()
