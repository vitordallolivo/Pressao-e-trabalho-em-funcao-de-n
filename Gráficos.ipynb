# %%
# código para criar gráfico 2D força elastica em função do número de elasticos

import numpy as np  
import matplotlib.pyplot as plt 
x= 919
y= 98.11

def P(n): return n*0.10676

n = np.linspace(0,1000)  
plt.title('Força Elastica em função de número de elasticos')

plt.plot(n, P(n))
plt.plot(x,y,marker="o")
plt.xlabel('Número de elasticos')
plt.ylabel('Força(N)')


plt.draw()
plt.savefig('forca elastica.png',dpi=100)
plt.show()

# %%
# Grafico 2D pressao melancia com o crescimento no número de elasticos

import numpy as np  
import matplotlib.pyplot as plt 

def P(n): return n*42.5
n = np.linspace(0,710)  
plt.plot(n,P(n))

plt.title('Pressão em função do número de elasticos')
plt.xlabel('Número de elasticos')
plt.ylabel('Pressão em Pascal(Pa)')

plt.grid()  
plt.savefig('pressao-grafico.png')
plt.show()

# %%
import numpy as np  
import matplotlib.pyplot as plt
vetory =[]
vetorx =[]
area=0.002512

for n in range(0,5000):
    area=area*1.0001
    pressao=(n*0.10676/area)
    vetory.append(pressao)
    vetorx.append(n)
    
def P(n): return n*42.5
n = np.linspace(1,5000)
plt.xlim(1,5000)

plt.title('Pressão em função do número de elasticos')
plt.xlabel('Número de elasticos(n)')
plt.ylabel('Pressão em Pascal(Pa)')

plt.plot(n,P(n))
plt.plot(vetory)
plt.savefig('Pressao e elasticos com acrescimo de 0,1 porcento.png') 
plt.show()

# %%
import numpy as np  
import matplotlib.pyplot as plt

p1=0.5024
p2=0.3768
vetorforca=[]
area =0.002512

for n in range(0,1000):
    
    p1 = area/0.005
    area = area/1.0001
    forca= n*0.85*(p1-p2)
    vetorforca.append(forca)

def P(n): return n*0.10676
n = np.linspace(0,1000)
plt.plot(n, P(n))
plt.title('Força Elastica em função de número de elasticos')
plt.xlabel('Número de elasticos')
plt.ylabel('Força(N)')
plt.plot(vetorforca)
plt.savefig('forca elastica com tudo') 
plt.show()
